# %%
# Write a program that asks the user for their name and age,then prints a sentence like:Hello Niharika, you are 20 years old !
name = input("Enter your name : ")
age = int(input("Enter your age : "))
print("Hello",name ,", you are ",age, "years old !")
# Out:
# Hello Niharika , you are  20 years old !

# %%
#Take two numbers as input from the user and print their sum,difference,product,and quotient
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 10
# 0
# 25
# 1.0

# %%
# Ask the user to enter two integers and one float. Convert them all to floats and print their average.
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = float(input("Enter third number : "))

a = float(a)
b = float(b)

avg = (a+b+c)/3

print(avg)
# Out:
# 10.0

# %%
# The user enters a string containing a number(e.g."45").Convert it to 
# •an integer •a float •a string again 
# Print all three values with their types.
s = input("Enter a number: ")

i = int(s)
f = float(s)
st = str(s)

print(i, type(i))
print(f, type(f))
print(st, type(st))
# Out:
# 15 <class 'int'>
# 15.0 <class 'float'>
# 15 <class 'str'>

# %%
# Evaluate and print the result of the following expression:
x =10+3*2**2
print(x)
# Out:
# 22

# %%
# Write a program to swap values of two numbers entered by the user
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

temp = a
a = b
b = temp

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# After swapping:
# a = 10
# b = 5

# %%
# Ask the user for a temperature in Celsius (string input).Convert it to float ,then calculate and print temperature in Fahrenheit.Conversion formula:Fahrenheit Temp=(CelsiusTemp∗(9/5))+32
celsius_str = input("Enter temperature in Celsius: ")

celsius = float(celsius_str)

fahrenheit = (celsius * (9/5)) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Temperature in Fahrenheit: 206.6

# %%
# Take the radius(r)as user input and print the area. use Area=π*r2(value of π=3.14)

r = float(input("Enter radius: "))

area = 3.14 * r * r

print("Area of circle:", area)
# Out:
# Area of circle: 50.24

# %%
# Ask the user for:Principal(P) ,Rate(R) ,Time(T).Convert all to float and compute simple interest:SI=(P∗R∗T)/100
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
T = float(input("Enter Time: "))

SI = (P * R * T) / 100

print("Simple Interest:", SI)
# Out:
# Simple Interest: 750.0

# %%
# Take a decimal number as input (like 45.78)and output its:integer part-45 and fractional part-.78
num = input("Enter a decimal number: ")

integer_part, fractional_part = num.split(".")

print("Integer part:", integer_part)
print("Fractional part: ." + fractional_part)
# Out:
# Integer part: 45
# Fractional part: .78

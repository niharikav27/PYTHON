# %%
#wap whichn element 13 at the end of the list numbers = [10,22,35,45,53] after tht print the list
numbers = [10,22,35,45,53]
numbers.append(13)
print(numbers)
# Out:
# [10, 22, 35, 45, 53, 13]

# %%
#wap which insert the element 20 at index 2 in the list numbers = [5,2,6,4,9].print the list
numbers = [5,3,6,4,9]
numbers.insert(2,20)
print(numbers)
# Out:
# [5, 3, 20, 6, 4, 9]

# %%
#if list1 =[1,2,3,4] and list2 = [8,6,7,5] then what should be the code for output [1,2,3,4,8,6,7,5]
list1 = [1,2,3,4]
list2 = [8,6,7,5]
result = list1 + list2       #list1.extend(list2)
print(result)
# Out:
# [1, 2, 3, 4, 8, 6, 7, 5]

# %%
#delete the element at index 3 from the list numbers = [10,2,36,41,5] and then print the list
numbers = [10,2,36,41,5]
numbers.pop(3)
print(numbers)
# Out:
# [10, 2, 36, 5]

# %%
#delete the element at index 4 from the list lst = ["apple","banana","orange","kiwi","guava"]
#print the list after deletion and also print that deleted element

lst = ["apple","banana","orange","kiwi","guava"]
element =lst.pop(4)
print(element)
print(lst)
# Out:
# guava
# ['apple', 'banana', 'orange', 'kiwi']

# %%
#remove the first occurence of the element 3 from the list numbers = [1,25,3,44,33,56] print the list after removing
numbers = [1,25,3,44,33,56]
numbers.remove(3)
print(numbers)
# Out:
# [1, 25, 44, 33, 56]

# %%
#count the numbers of times the element 2 appears in the list lst = [15,2,2,3,4,2,7,8,45,2,2] and print the count
lst = [15,2,2,3,4,2,7,8,45,2,2]
cnt = lst.count(2)
print(cnt)
# Out:
# 5

# %%
#wap which prints the reverse list of the given list
lst = [15,22,35,24,65]
lst.reverse()
print(lst)
# Out:
# [65, 24, 35, 22, 15]

# %%
#wap to which add the element 7 at the last of the list lst = [4,2,5,1,3,6,8,10,3,5] then sort the list
#print the list after these operations

lst = [4,2,5,1,3,6,8,10,3,5]
lst.append(7)
lst.sort()
print(lst)
# Out:
# [1, 2, 3, 3, 4, 5, 5, 6, 7, 8, 10]

# %%
#wap which insert the element 10 at index 1 in the list lst = [12,24,35,24,45] 
#then remove the element 35.print the list after these operations
lst = [12,24,35,24,45]
lst.insert(1,10)
lst.remove(35)
print(lst)
# Out:
# [12, 10, 24, 24, 45]

# %%
#wap which iterates the given list prints all the values inside the list via loop
lst = ['mango','apple','banana','orange','kiwi']
for item in lst:
    print(item)
# Out:
# mango
# apple
# banana
# orange
# kiwi

# %%
#wap which finds the sum to all the elements of the list by iterating that given list
lst =[2,4,6,8,12,10,14,24]
total = 0
for num in lst:
    total += num 

print(total)
# Out:
# 80

# %%
#wap which find the values (n) in the given list =[4,5,3,2,1,6,8] if present then return true otherwise false

n = int(input("Enter a number : "))    #6
lst = [4,5,3,2,1,6,8]
print(n in lst)
# Out:
# True

# %%
#wap which update odd indices element of the list by "hii" through iterating that given list
lst = [2,4,6,8,1]

for i in range(len(lst)):
    if i % 2 != 0:
        lst[i] = "hii"

print(lst)
# Out:
# [2, 'hii', 6, 'hii', 1]

# %%
#wap which finds and print the average of elements of the given list of integers
lst = [10,45,23,46,98,56]
total = 0 
for num in lst:
    total += num 
avg = total / len(lst)
print(avg)
# Out:
# 46.333333333333336

# %%
#wap which finds the sum of squares of all elements of the given list 
lst = [2,4,6,8,1]
for i in range(len(lst)):
    lst[i] = lst[i]**2

print(lst)
# Out:
# [4, 16, 36, 64, 1]
